# %%
#Problema asignacion de salas


#Funcion curso:
'''
    -id
    -cantidad estudiantes
    -horario inicio - termino
    -Requisitos
'''
#Definimos una funcion para ahorrar espacio en el codigo y presentar de manera mas elegante las condiciones de cada uno.
def verificar(X):
    while True:
        if 1<=X<=100:
            return X
        else:
            X=int(input("Solo numeros entre 1 y 100: "))

#Garantizar C entre 1 a 100:
C=int(input("Ingrese número de cursos: "))
C=verificar(C)#?? Para adoptar el valor actualizado al corregirse en el verificador
S=int(input("Ingrese número de salas: "))
S=verificar(S)#?? Para adoptar el valor actualizado al corregirse en el verificador

        
#definimos la funcion para verificar el horario que este acorde a los rangos 0<=inicio<fin<24
def verificarH(I,F):
    while True:
        if 0<=I<F<=24:
            return I,F
        else:
            I=int(input("Hora de inicio debe ser menor que hora de fin y mayor que las 0hrs: "))
            F=int(input("Hora de fin debe ser mayor que hora de inicio y menor que 24hrs: "))


#Definiendo los cursos
def curso():
    #If theres " " in Id_curso:
    ID_curso=str(input("Ingrese ID del curso: "))
    while True: # Restriccion para que solo se escriba sin espacios
        if " " in ID_curso:
            ID_curso=str(input("Ingrese ID (sin espacios): "))
        else:
            break #Rompemos el loop para que siga pidiendop el resto de argumentos
    estudiantes=int(input("Numero de estudiantes: ")) 
    inicio1=int(input("Hora inicio: "))
    fin1=int(input("Hora final: "))
    inicio1,fin1=verificarH(inicio1,fin1)
    #Verificador de que cumpla con las condiciones exigidas anteriormente para el horario
    k=int(input("Ingrese cantidad de requisitos para el curso: "))
    listareqcurso=[] #los requisitos seran enlistados se guardaran y luego los compararemos, lo definiremos antes para que luego sepa donde guardarlos datos en el append
    for i in range(0,k): #cantidad de veces que iteraremos los requisitos para poder caracterizarlo
        req_i=str(input("Ingrese los requisitos del curso: "))
        listareqcurso.append(req_i) #Serán añadidos a la lista de los requerimientos del curso. por cada cantidad de requisitos que sea necesario

    return ID_curso,estudiantes,inicio1,fin1,listareqcurso
#####################################
for i in range(1,C):
    curso()
####################################
#Definiendo las salas, se iteran condiciones similares a la primera funcion asignada
def sala():
    ID_sala=str(input("Ingrese ID de la sala: "))
    while True:
        if " " in ID_sala:
            ID_sala=str(input("Ingrese ID de la sala (sin espacios): "))
        else:
            break
    capacidad=int(input("Ingrese capacidad de estudiantes de la sala: "))
    listahorarios=[]
    listahorarios.append(inicio1,fin1)
    m=int(input("Ingrese cantidad de requisitos para la sala: "))
    listareqsala=[]
    for j in range (0,m):
        req_j=str(input("Ingrese requisitos de la sala: "))
        listareqsala.append(req_j)

    return ID_sala,capacidad,listahorarios,listareqsala
#Funcion desempaquetar.
ID_curso,estudiantes,inicio1,fin1,listareqcurso=curso()
ID_sala,capacidad,listahorarios,listareqsala=sala()
#######################################
for j in range(1,S):
    sala()
#######################################

print(listahorarios)
# Out:
# Ingrese número de cursos:  3
# Ingrese número de salas:  2
# Ingrese ID del curso:  INF 101
# Ingrese ID (sin espacios):  INF 101
# Ingrese ID (sin espacios):  INF 101

# %%
#

# %%
def curso():
    ID_curso = str(input("Ingrese el ID del curso: "))
    students = int(input("Ingrese el número de estudiantes: "))
    schedule_inicio = input("Ingrese el bloque de inicio: ")
    schedule_final = input("Ingrese el bloque de termino: ")
    requisitos = input("Ingrese los requisitos del curso: ")
 
def sala():
    ID_sala = str(input("Ingrese el ID de la sala: "))
    capacidad = int(input("Ingrese la capacidad de la sala: "))
    disponibilidad_inicio = input("Ingrese el bloque de inicio: ")
    disponibilidad_final = input("Ingrese el bloque de termino: ")
    caracteristicas = input("Ingrese las características de la sala: ")
 
while True:
    numero_cursos = int(input("Ingrese el número de cursos a agregar: "))
    numero_salas = int(input("Ingrese el número de salas a agregar: "))
    if numero_cursos < 1 or numero_salas > 100:
        print("Numero de cursos o salas no valido.")
    else:              
        for i in range(numero_cursos):
            curso()
        for i in range(numero_salas):
            sala()  
        break                
 
#Falta almacenar datos para luego hacer comparaciones y saber que salas puede ocupar un curso dado.
# Out:
# Ingrese el número de cursos a agregar:  3
# Ingrese el número de salas a agregar:  2
# Ingrese el ID del curso:  INF101
# Ingrese el número de estudiantes:  30
# Ingrese el bloque de inicio:  8
# Ingrese el bloque de termino:  10
# Ingrese los requisitos del curso:  1
# Ingrese el ID del curso:  MAT202
# Ingrese el número de estudiantes:  50
# Ingrese el bloque de inicio:  9
# Ingrese el bloque de termino:  11
# Ingrese los requisitos del curso:  0
# Ingrese el ID del curso:  QUI303
# Ingrese el número de estudiantes:  20
# Ingrese el bloque de inicio:  10
# Ingrese el bloque de termino:  12
# Ingrese los requisitos del curso:  1
# Ingrese el ID de la sala:  SALA1
# Ingrese la capacidad de la sala:  40
# Ingrese el bloque de inicio:  1
# Ingrese el bloque de termino:  12
# Ingrese las características de la sala:  proyector
# Ingrese el ID de la sala:  SALA2
# Ingrese la capacidad de la sala:  25
# Ingrese el bloque de inicio:  1
# Ingrese el bloque de termino:  12
# ...
